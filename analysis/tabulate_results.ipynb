# %%
# %cd ~/alde4ssmula
# Out:
# /disk2/fli/alde4ssmula

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import torch
from datetime import datetime
import glob
import os
import math
import pandas as pd

# %%
def index2regret(indices, y):
    """
    Converts list of queried indices to regret (difference between the max value in the deisgn space and the max queired value)
    """
    indices = np.array(indices, dtype=int)
    regret = torch.zeros((indices.shape[0], indices.shape[1]))
    for i in range(indices.shape[0]):
        for j in range(indices.shape[1]):
            regret[i, j] = 1 - y[indices[i, :j+1]].max()
    return regret

# %%
def load_tensors(subdir):
    """
    loads al indices from a directory and converts them to regret values
    """
    tensors = sorted(glob.glob(subdir + '/*indices*.pt'))
        
    tests = {}
    print('Models not included/not over budget yet:\n')

    for tensor in tensors:
        num = int(tensor.split('indices')[0].split('_')[-1])

        if '.pt' in tensor and 'state_dict' not in tensor:
            first = False
            if "Random" not in os.path.basename(tensor):
                nm = os.path.basename(tensor).split('_')[0] + '_' + os.path.basename(tensor).split('_')[1]
            else:     
                nm = os.path.basename(tensor).split('_')[0]

            t = torch.load(tensor).cpu().detach()
            t = torch.reshape(t, (1, -1))

            # lim = 480
            # if t.size(-1) < lim:
            #     if 'indices.pt' in tensor:
            #         print(tensor.split('/')[-1])
            #     continue
            if nm in tests.keys():
                d = tests[nm]
            else:
                d = {}
                tests[nm] = d

            dtype = os.path.basename(tensor).split('_')[-1].split('.')[0]
            dtype = ''.join([i for i in dtype if not i.isdigit()])
            if dtype in d.keys():
                arr = d[dtype]
            else:
                arr = t
                d[dtype] = arr
                first = True
            if first:
                pass
            elif t.size(-1) < arr.size(-1):
                arr = torch.cat((arr[:,:t.size(-1)], t), 0)
            else:
                arr = torch.cat((arr, t[:,:arr.size(-1)]), 0)
            d[dtype] = arr
            tests[nm] = d

    print('\nModels included:\n')
    batch = {}
    budget, total= math.inf, math.inf
    for key in tests.keys():
        print(key)
        num_runs = -1
        for dtype in tests[key].keys():
            t = tests[key][dtype]
            t = index2regret(t, y)
            
            if 'indices' == dtype and t.size(-1) != 0:
                if t.size(-1) < budget:
                    budget = t.size(-1)
                num_runs = t.size(0)
            elif 'y' in dtype and t.size(-1) < total and t.size(-1) != 0:
                total = t.size(-1)
            
            sd, mean = torch.std_mean(t, 0)
            sem = sd / (t.size(0)**.5)
            if dtype in batch.keys():
                d = batch[dtype]
            else:
                d = {}
                batch[dtype] = d

            d[key] = (mean, sem)

            batch[dtype] = d
        print("Runs: {}".format(num_runs))
    print(batch.keys())
    print('Budget: {}'.format(budget))
    print('Total queries (incl. init): {}'.format(budget))

    return batch, budget

# %%
def tabulate_regret(df, tests, budget, subdir, randregret=None):
    """
    Tabulates loaded regret values into an organized dataframe.
    """
    names = []
    queries = np.arange(budget) + 1
    
    for name in sorted(tests.keys()):
        names.append(name)

        mean, sem = tests[name]
        mean = 1 - mean
        if mean.size(0) < budget:
            names.pop()
            continue
        if mean.size(0) > budget:
            mean = mean[:budget]
            sem = sem[:budget]

        protein = subdir.split('/')[-2]
        encoding = subdir.split('/')[-1]

        if 'Random' in name:
            encoding = 'Random'
            model = 'Random'
            acquisition = 'Random'
        else:
            names = name.split('-')
            model = names[0]
            acquisition = names[-2]

        for timestep, single_mean, single_std in zip(queries, np.array(mean), np.array(sem)):
            df.loc[len(df.index)] = [protein, encoding, model, acquisition, timestep, single_mean, single_std]
    return df

# %%
for res_dir in (glob.glob('results/all_*')):
# for res_dir in (glob.glob('results/1920+96+baseline')):
    print(res_dir)

    #Loop over different datasets and encodings
    #tabulate all max fitness values into one dataframe
    df = pd.DataFrame(columns=['Protein', 'Encoding', 'Model', 'Acquisition', 'Timestep', 'Mean', 'Std'])

    for protein in ["DHFR", "GB1", "ParD2", "ParD3", "TrpB3A", "TrpB3B", "TrpB3C", "TrpB3D", "TrpB3E", "TrpB3F", "TrpB3G", "TrpB3H", "TrpB3I", "TrpB4"]:
        for encoding in ['onehot']:
            subdir =  res_dir + '/' + protein + '/' + encoding
            fitness_df = pd.read_csv('data/' + protein + '/fitness.csv')
            y = fitness_df['fitness'].values
            y = y/y.max()

            print(subdir)
        
            batch, budget = load_tensors(subdir)
            
            df = tabulate_regret(df, batch['indices'], budget, subdir, randregret=None)

    #clean up the results and save
    df = df.drop_duplicates(subset=['Protein', 'Encoding', 'Model', 'Acquisition', 'Timestep'], keep='first')
    df['Model'] = df['Model'].replace('BOOSTING_ENSEMBLE', 'Boosting Ensemble')
    df['Model'] = df['Model'].replace('GP_BOTORCH', 'GP')
    df['Model'] = df['Model'].replace('DNN_ENSEMBLE', 'DNN Ensemble')
    df['Model'] = df['Model'].replace('DKL_BOTORCH', 'DKL')
    df['Acquisition'] = df['Acquisition'].replace('Random', 'GREEDY')
    df.to_csv(res_dir + '/all_results.csv', index=False)

    del df
# Out:
# results/all_384+96
# results/all_384+96/DHFR/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 480
# Total queries (incl. init): 480
# results/all_384+96/GB1/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 480
# Total queries (incl. init): 480
# results/all_384+96/ParD2/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 480
# Total queries (incl. init): 480
# results/all_384+96/ParD3/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 480
# Total queries (incl. init): 480
# results/all_384+96/TrpB3A/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 480
# Total queries (incl. init): 480
# results/all_384+96/TrpB3B/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 480
# Total queries (incl. init): 480
# results/all_384+96/TrpB3C/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 480
# Total queries (incl. init): 480
# results/all_384+96/TrpB3D/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 480
# Total queries (incl. init): 480
# results/all_384+96/TrpB3E/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 480
# Total queries (incl. init): 480
# results/all_384+96/TrpB3F/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 480
# Total queries (incl. init): 480
# results/all_384+96/TrpB3G/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 480
# Total queries (incl. init): 480
# results/all_384+96/TrpB3H/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 480
# Total queries (incl. init): 480
# results/all_384+96/TrpB3I/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 480
# Total queries (incl. init): 480
# results/all_384+96/TrpB4/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 480
# Total queries (incl. init): 480
# results/all_192+96
# results/all_192+96/DHFR/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 288
# Total queries (incl. init): 288
# results/all_192+96/GB1/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 288
# Total queries (incl. init): 288
# results/all_192+96/ParD2/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 288
# Total queries (incl. init): 288
# results/all_192+96/ParD3/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 288
# Total queries (incl. init): 288
# results/all_192+96/TrpB3A/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 288
# Total queries (incl. init): 288
# results/all_192+96/TrpB3B/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 288
# Total queries (incl. init): 288
# results/all_192+96/TrpB3C/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 288
# Total queries (incl. init): 288
# results/all_192+96/TrpB3D/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 288
# Total queries (incl. init): 288
# results/all_192+96/TrpB3E/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 288
# Total queries (incl. init): 288
# results/all_192+96/TrpB3F/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 288
# Total queries (incl. init): 288
# results/all_192+96/TrpB3G/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 288
# Total queries (incl. init): 288
# results/all_192+96/TrpB3H/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 288
# Total queries (incl. init): 288
# results/all_192+96/TrpB3I/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 288
# Total queries (incl. init): 288
# results/all_192+96/TrpB4/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 288
# Total queries (incl. init): 288
# results/all_288+96
# results/all_288+96/DHFR/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 384
# Total queries (incl. init): 384
# results/all_288+96/GB1/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 384
# Total queries (incl. init): 384
# results/all_288+96/ParD2/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 384
# Total queries (incl. init): 384
# results/all_288+96/ParD3/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 384
# Total queries (incl. init): 384
# results/all_288+96/TrpB3A/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 384
# Total queries (incl. init): 384
# results/all_288+96/TrpB3B/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 384
# Total queries (incl. init): 384
# results/all_288+96/TrpB3C/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 384
# Total queries (incl. init): 384
# results/all_288+96/TrpB3D/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 384
# Total queries (incl. init): 384
# results/all_288+96/TrpB3E/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 384
# Total queries (incl. init): 384
# results/all_288+96/TrpB3F/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 384
# Total queries (incl. init): 384
# results/all_288+96/TrpB3G/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 384
# Total queries (incl. init): 384
# results/all_288+96/TrpB3H/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 384
# Total queries (incl. init): 384
# results/all_288+96/TrpB3I/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 384
# Total queries (incl. init): 384
# results/all_288+96/TrpB4/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 384
# Total queries (incl. init): 384
# results/all_576+96
# results/all_576+96/DHFR/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 672
# Total queries (incl. init): 672
# results/all_576+96/GB1/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 672
# Total queries (incl. init): 672
# results/all_576+96/ParD2/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 672
# Total queries (incl. init): 672
# results/all_576+96/ParD3/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 672
# Total queries (incl. init): 672
# results/all_576+96/TrpB3A/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 672
# Total queries (incl. init): 672
# results/all_576+96/TrpB3B/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 672
# Total queries (incl. init): 672
# results/all_576+96/TrpB3C/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 672
# Total queries (incl. init): 672
# results/all_576+96/TrpB3D/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 672
# Total queries (incl. init): 672
# results/all_576+96/TrpB3E/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 672
# Total queries (incl. init): 672
# results/all_576+96/TrpB3F/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 672
# Total queries (incl. init): 672
# results/all_576+96/TrpB3G/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 672
# Total queries (incl. init): 672
# results/all_576+96/TrpB3H/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 672
# Total queries (incl. init): 672
# results/all_576+96/TrpB3I/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 672
# Total queries (incl. init): 672
# results/all_576+96/TrpB4/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 672
# Total queries (incl. init): 672
# results/all_480+96
# results/all_480+96/DHFR/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 576
# Total queries (incl. init): 576
# results/all_480+96/GB1/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 576
# Total queries (incl. init): 576
# results/all_480+96/ParD2/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 576
# Total queries (incl. init): 576
# results/all_480+96/ParD3/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 576
# Total queries (incl. init): 576
# results/all_480+96/TrpB3A/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 576
# Total queries (incl. init): 576
# results/all_480+96/TrpB3B/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 576
# Total queries (incl. init): 576
# results/all_480+96/TrpB3C/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 576
# Total queries (incl. init): 576
# results/all_480+96/TrpB3D/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 576
# Total queries (incl. init): 576
# results/all_480+96/TrpB3E/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 576
# Total queries (incl. init): 576
# results/all_480+96/TrpB3F/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 576
# Total queries (incl. init): 576
# results/all_480+96/TrpB3G/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 576
# Total queries (incl. init): 576
# results/all_480+96/TrpB3H/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# ...
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 2016
# Total queries (incl. init): 2016
# results/all_1920+96/TrpB3C/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 2016
# Total queries (incl. init): 2016
# results/all_1920+96/TrpB3D/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 2016
# Total queries (incl. init): 2016
# results/all_1920+96/TrpB3E/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 2016
# Total queries (incl. init): 2016
# results/all_1920+96/TrpB3F/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 2016
# Total queries (incl. init): 2016
# results/all_1920+96/TrpB3G/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 2016
# Total queries (incl. init): 2016
# results/all_1920+96/TrpB3H/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 2016
# Total queries (incl. init): 2016
# results/all_1920+96/TrpB3I/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 2016
# Total queries (incl. init): 2016
# results/all_1920+96/TrpB4/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 2016
# Total queries (incl. init): 2016
# results/all_960+96
# results/all_960+96/DHFR/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 1056
# Total queries (incl. init): 1056
# results/all_960+96/GB1/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 1056
# Total queries (incl. init): 1056
# results/all_960+96/ParD2/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 1056
# Total queries (incl. init): 1056
# results/all_960+96/ParD3/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 1056
# Total queries (incl. init): 1056
# results/all_960+96/TrpB3A/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 1056
# Total queries (incl. init): 1056
# results/all_960+96/TrpB3B/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 1056
# Total queries (incl. init): 1056
# results/all_960+96/TrpB3C/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 1056
# Total queries (incl. init): 1056
# results/all_960+96/TrpB3D/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 1056
# Total queries (incl. init): 1056
# results/all_960+96/TrpB3E/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 1056
# Total queries (incl. init): 1056
# results/all_960+96/TrpB3F/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 1056
# Total queries (incl. init): 1056
# results/all_960+96/TrpB3G/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 1056
# Total queries (incl. init): 1056
# results/all_960+96/TrpB3H/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 1056
# Total queries (incl. init): 1056
# results/all_960+96/TrpB3I/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[60, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[60, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 1056
# Total queries (incl. init): 1056
# results/all_960+96/TrpB4/onehot
# Models not included/not over budget yet:
#
#
# Models included:
#
# BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-TS-[80, 1]
# Runs: 50
# BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]
# Runs: 50
# DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-GREEDY-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-TS-[80, 1]
# Runs: 50
# GP_BOTORCH-DO-0-RBF-UCB-[80, 1]
# Runs: 50
# Random
# Runs: 50
# dict_keys(['indices'])
# Budget: 1056
# Total queries (incl. init): 1056

# %%
df = pd.read_csv("/disk2/fli/alde4ssmula/results/all_384+96/all_results.csv")

# %%
df[(df["Encoding"]=="onehot") & (df["Acquisition"] == "GREEDY") & (df["Timestep"] == 480)]
# Out:
#       Protein Encoding              Model Acquisition  Timestep      Mean  \
# 479      DHFR   onehot  Boosting Ensemble      GREEDY       480  0.926345
# 1919     DHFR   onehot                DKL      GREEDY       480  0.910559
# 3359     DHFR   onehot       DNN Ensemble      GREEDY       480  0.903667
# 4799     DHFR   onehot                 GP      GREEDY       480  0.912401
# 6719      GB1   onehot  Boosting Ensemble      GREEDY       480  0.727046
# 8159      GB1   onehot                DKL      GREEDY       480  0.696614
# 9599      GB1   onehot       DNN Ensemble      GREEDY       480  0.750532
# 11039     GB1   onehot                 GP      GREEDY       480  0.678931
# 12959   ParD2   onehot  Boosting Ensemble      GREEDY       480  0.999825
# 14399   ParD2   onehot                DKL      GREEDY       480  0.999449
# 15839   ParD2   onehot       DNN Ensemble      GREEDY       480  1.000000
# 17279   ParD2   onehot                 GP      GREEDY       480  0.987952
# 19199   ParD3   onehot  Boosting Ensemble      GREEDY       480  0.991750
# 20639   ParD3   onehot                DKL      GREEDY       480  0.991979
# 22079   ParD3   onehot       DNN Ensemble      GREEDY       480  0.989638
# 23519   ParD3   onehot                 GP      GREEDY       480  0.988581
# 25439  TrpB3A   onehot  Boosting Ensemble      GREEDY       480  0.397686
# 26879  TrpB3A   onehot                DKL      GREEDY       480  0.397700
# 28319  TrpB3A   onehot       DNN Ensemble      GREEDY       480  0.399707
# 29759  TrpB3A   onehot                 GP      GREEDY       480  0.394275
# 31679  TrpB3B   onehot  Boosting Ensemble      GREEDY       480  0.223546
# 33119  TrpB3B   onehot                DKL      GREEDY       480  0.219584
# 34559  TrpB3B   onehot       DNN Ensemble      GREEDY       480  0.219586
# 35999  TrpB3B   onehot                 GP      GREEDY       480  0.218782
# 37919  TrpB3C   onehot  Boosting Ensemble      GREEDY       480  0.347745
# 39359  TrpB3C   onehot                DKL      GREEDY       480  0.377395
# 40799  TrpB3C   onehot       DNN Ensemble      GREEDY       480  0.357302
# 42239  TrpB3C   onehot                 GP      GREEDY       480  0.373174
# 44159  TrpB3D   onehot  Boosting Ensemble      GREEDY       480  0.719972
# 45599  TrpB3D   onehot                DKL      GREEDY       480  0.731027
# 47039  TrpB3D   onehot       DNN Ensemble      GREEDY       480  0.721060
# 48479  TrpB3D   onehot                 GP      GREEDY       480  0.722447
# 50399  TrpB3E   onehot  Boosting Ensemble      GREEDY       480  0.321670
# 51839  TrpB3E   onehot                DKL      GREEDY       480  0.313105
# 53279  TrpB3E   onehot       DNN Ensemble      GREEDY       480  0.295033
# 54719  TrpB3E   onehot                 GP      GREEDY       480  0.332753
# 56639  TrpB3F   onehot  Boosting Ensemble      GREEDY       480  0.341888
# 58079  TrpB3F   onehot                DKL      GREEDY       480  0.363822
# 59519  TrpB3F   onehot       DNN Ensemble      GREEDY       480  0.352908
# 60959  TrpB3F   onehot                 GP      GREEDY       480  0.346327
# 62879  TrpB3G   onehot  Boosting Ensemble      GREEDY       480  0.577691
# 64319  TrpB3G   onehot                DKL      GREEDY       480  0.600303
# 65759  TrpB3G   onehot       DNN Ensemble      GREEDY       480  0.571614
# 67199  TrpB3G   onehot                 GP      GREEDY       480  0.570518
# 69119  TrpB3H   onehot  Boosting Ensemble      GREEDY       480  0.320912
# 70559  TrpB3H   onehot                DKL      GREEDY       480  0.339063
# 71999  TrpB3H   onehot       DNN Ensemble      GREEDY       480  0.335788
# 73439  TrpB3H   onehot                 GP      GREEDY       480  0.316541
# 75359  TrpB3I   onehot  Boosting Ensemble      GREEDY       480  0.604166
# 76799  TrpB3I   onehot                DKL      GREEDY       480  0.600164
# 78239  TrpB3I   onehot       DNN Ensemble      GREEDY       480  0.599540
# 79679  TrpB3I   onehot                 GP      GREEDY       480  0.606098
# 81599   TrpB4   onehot  Boosting Ensemble      GREEDY       480  0.566384
# 83039   TrpB4   onehot                DKL      GREEDY       480  0.574689
# 84479   TrpB4   onehot       DNN Ensemble      GREEDY       480  0.574924
# 85919   TrpB4   onehot                 GP      GREEDY       480  0.566508
#
#             Std
# 479    0.009593
# 1919   0.009958
# 3359   0.010632
# 4799   0.010571
# 6719   0.017082
# 8159   0.018616
# 9599   0.018383
# 11039  0.015871
# 12959  0.000175
# 14399  0.000411
# 15839  0.000000
# 17279  0.001288
# 19199  0.000826
# 20639  0.000840
# 22079  0.000567
# 23519  0.001424
# 25439  0.047483
# 26879  0.047940
# 28319  0.047229
# 29759  0.047817
# 31679  0.033450
# 33119  0.033149
# 34559  0.033204
# 35999  0.032790
# 37919  0.027111
# 39359  0.030872
# 40799  0.026715
# 42239  0.029569
# 44159  0.024171
# 45599  0.024110
# 47039  0.023945
# 48479  0.023678
# 50399  0.044584
# 51839  0.041654
# 53279  0.042731
# 54719  0.043702
# 56639  0.035473
# 58079  0.036977
# 59519  0.034582
# 60959  0.035156
# 62879  0.033777
# 64319  0.031450
# 65759  0.036346
# 67199  0.035499
# 69119  0.047456
# 70559  0.049518
# 71999  0.048256
# 73439  0.047471
# 75359  0.008682
# 76799  0.008897
# 78239  0.008979
# 79679  0.008462
# 81599  0.015695
# 83039  0.017185
# 84479  0.015302
# 85919  0.014530

# %%
def checkNgen_folder(folder_path: str) -> str:

    """
    Check if the folder and its subfolder exists
    create a new directory if not
    Args:
    - folder_path: str, the folder path
    """

    split_list = os.path.normpath(folder_path).split("/")
    
    # check if absolute
    if os.path.isabs(folder_path):
        split_list[0] = "/" + split_list[0]

    for p, _ in enumerate(split_list):
        subfolder_path = "/".join(split_list[: p + 1])
        if not os.path.exists(subfolder_path):
            print(f"Making {subfolder_path} ...")
            os.mkdir(subfolder_path)
    return folder_path
def preprocessing_data(path_pattern: str = 'data_original/*/*.csv') -> None:
    for file_path in glob.glob(path_pattern):
        output_path = file_path.replace('data_original', 'data')
        checkNgen_folder(os.path.dirname(output_path))

        df = pd.read_csv(file_path)
        # get rid of rows with * in the name of AAs
        df = df[~df['AAs'].str.contains('\*')].copy()
        df = df.rename(columns={'AAs': 'Combo'})
        df[["Combo", "fitness"]].copy().to_csv(output_path, index=False)
        print(f'Processed {file_path}')

# %%
preprocessing_data()
# Out:
# Making data ...
# Making data/TrpB4 ...
# Processed data_original/TrpB4/fitness.csv
# Making data/ParD2 ...
# Processed data_original/ParD2/fitness.csv
# Making data/TrpB3H ...
# Processed data_original/TrpB3H/fitness.csv
# Making data/ParD3 ...
# Processed data_original/ParD3/fitness.csv
# Making data/TrpB3B ...
# Processed data_original/TrpB3B/fitness.csv
# Making data/DHFR ...
# Processed data_original/DHFR/fitness.csv
# Making data/TrpB3D ...
# Processed data_original/TrpB3D/fitness.csv
# Making data/TrpB3A ...
# Processed data_original/TrpB3A/fitness.csv
# Making data/TrpB3I ...
# Processed data_original/TrpB3I/fitness.csv
# Making data/GB1 ...
# Processed data_original/GB1/fitness.csv
# Making data/TrpB3F ...
# Processed data_original/TrpB3F/fitness.csv
# Making data/TrpB3C ...
# Processed data_original/TrpB3C/fitness.csv
# Making data/TrpB3E ...
# Processed data_original/TrpB3E/fitness.csv
# Making data/TrpB3G ...
# Processed data_original/TrpB3G/fitness.csv
